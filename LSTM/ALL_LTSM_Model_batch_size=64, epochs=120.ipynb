# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)


import wave
# Out:
# TensorFlow version: 2.6.0

# %%
import librosa
import pandas as pd
import os
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Activation , Dropout

import IPython.display as ip

# %%
#importing  libraries
#Keras
import tensorflow.keras
from tensorflow.keras import regularizers, layers
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, Model, model_from_json
from tensorflow.keras.layers import Dense, Embedding, LSTM
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling1D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

#sklearn
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

#Others
import librosa
import librosa.display
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import tensorflow as tf
import pandas as pd
import seaborn as sns
import glob
import os
import pickle
import IPython.display as ipd
import csv
from tqdm import tqdm
import os


import sys
import os
import IPython
import math
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

import random
from datetime import datetime
#from include import helpers

from tensorflow.keras import backend as keras_backend
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SpatialDropout2D, Activation, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.regularizers import l2

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %%
#split the dataset into train and test
X_train = pd.read_csv('https://raw.githubusercontent.com/fatmaaerr/ML_Urbansound8k_project/main/Data/X_train_all.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/fatmaaerr/ML_Urbansound8k_project/main/Data/y_train_all.csv')
X_test = pd.read_csv('https://raw.githubusercontent.com/fatmaaerr/ML_Urbansound8k_project/main/Data/X_test_all.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/fatmaaerr/ML_Urbansound8k_project/main/Data/y_test_all.csv')
#take a peak at the data
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((4499, 42), (4499, 1), (4233, 43), (4233, 2))

# %%
#One hot encode labels

le = LabelEncoder()

def encoding_y(data):
  data = np.array(data['label'])
  data = to_categorical(le.fit_transform(data))
  return data

y_train = encoding_y(y_train)
y_test = encoding_y(y_test)

# %%
X_test = X_test.iloc[:,1:43]

def standardization(data):
  mean = np.mean(data,axis=0)
  std = np.std(data, axis=0)
  data =( data - mean)/std
  data = np.array(data)
  data=np.reshape(data,(data.shape[0],42, 1))
  return data

X_train = standardization(X_train)
X_test = standardization(X_test)

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.LSTM(
         units=128,activation='relu',
         return_sequences=True,
         input_shape=(40,1)
     ),
     tf.keras.layers.LSTM(
         units=64,activation='relu'
     ),
     tf.keras.layers.Dense(
         units=32,
         activation='relu'
     ),

     tf.keras.layers.Dense(
         units=10,
         activation='softmax'
     )

    ]
)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 40, 128)           66560
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 118,378
# Trainable params: 118,378
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Train...")
model_all=model.fit(X_train, y_train, batch_size=64, epochs=120, validation_data=(X_test, y_test))
# Out:
# Train...
# Epoch 1/120
# WARNING:tensorflow:Model was constructed with shape (None, 40, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 40, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 42, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 40, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 40, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 42, 1).
# 71/71 [==============================] - ETA: 0s - loss: 2.2418 - accuracy: 0.1680WARNING:tensorflow:Model was constructed with shape (None, 40, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 40, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 42, 1).
# 71/71 [==============================] - 6s 61ms/step - loss: 2.2418 - accuracy: 0.1680 - val_loss: 2.2635 - val_accuracy: 0.1621
# Epoch 2/120
# 71/71 [==============================] - 4s 56ms/step - loss: 2.1452 - accuracy: 0.2072 - val_loss: 2.1395 - val_accuracy: 0.2105
# Epoch 3/120
# 71/71 [==============================] - 4s 56ms/step - loss: 2.0517 - accuracy: 0.2423 - val_loss: 2.1314 - val_accuracy: 0.1810
# Epoch 4/120
# 71/71 [==============================] - 4s 54ms/step - loss: 1.9982 - accuracy: 0.2547 - val_loss: 2.0354 - val_accuracy: 0.2733
# Epoch 5/120
# 71/71 [==============================] - 4s 55ms/step - loss: 1.9262 - accuracy: 0.2805 - val_loss: 2.0222 - val_accuracy: 0.2757
# Epoch 6/120
# 71/71 [==============================] - 5s 64ms/step - loss: 1.8152 - accuracy: 0.3118 - val_loss: 1.9271 - val_accuracy: 0.3255
# Epoch 7/120
# 71/71 [==============================] - 5s 70ms/step - loss: 1.6525 - accuracy: 0.3910 - val_loss: 2.0052 - val_accuracy: 0.3272
# Epoch 8/120
# 71/71 [==============================] - 5s 73ms/step - loss: 1.5391 - accuracy: 0.4428 - val_loss: 1.7642 - val_accuracy: 0.4139
# Epoch 9/120
# 71/71 [==============================] - 5s 74ms/step - loss: 1.4086 - accuracy: 0.5057 - val_loss: 1.7568 - val_accuracy: 0.4304
# Epoch 10/120
# 71/71 [==============================] - 5s 72ms/step - loss: 1.2551 - accuracy: 0.5583 - val_loss: 1.7020 - val_accuracy: 0.4177
# Epoch 11/120
# 71/71 [==============================] - 5s 71ms/step - loss: 1.1670 - accuracy: 0.5957 - val_loss: 1.7821 - val_accuracy: 0.4321
# Epoch 12/120
# 71/71 [==============================] - 5s 71ms/step - loss: 1.1032 - accuracy: 0.6184 - val_loss: 1.7127 - val_accuracy: 0.4274
# Epoch 13/120
# 71/71 [==============================] - 5s 70ms/step - loss: 1.0443 - accuracy: 0.6433 - val_loss: 1.8594 - val_accuracy: 0.4132
# Epoch 14/120
# 71/71 [==============================] - 5s 72ms/step - loss: 1.0012 - accuracy: 0.6601 - val_loss: 1.8305 - val_accuracy: 0.4304
# Epoch 15/120
# 71/71 [==============================] - 5s 73ms/step - loss: 5.0277 - accuracy: 0.2012 - val_loss: 2.3079 - val_accuracy: 0.1368
# Epoch 16/120
# 71/71 [==============================] - 5s 69ms/step - loss: 4.4915 - accuracy: 0.1587 - val_loss: 2.2569 - val_accuracy: 0.1240
# Epoch 17/120
# 71/71 [==============================] - 5s 69ms/step - loss: 2.1949 - accuracy: 0.1765 - val_loss: 2.1793 - val_accuracy: 0.1658
# Epoch 18/120
# 71/71 [==============================] - 5s 75ms/step - loss: 2.1123 - accuracy: 0.2109 - val_loss: 2.1173 - val_accuracy: 0.1923
# Epoch 19/120
# 71/71 [==============================] - 5s 69ms/step - loss: 2.0650 - accuracy: 0.2547 - val_loss: 2.0666 - val_accuracy: 0.2445
# Epoch 20/120
# 71/71 [==============================] - 5s 70ms/step - loss: 1.9856 - accuracy: 0.3098 - val_loss: 2.0084 - val_accuracy: 0.2764
# Epoch 21/120
# 71/71 [==============================] - 5s 74ms/step - loss: 1.9221 - accuracy: 0.3307 - val_loss: 1.9464 - val_accuracy: 0.2996
# Epoch 22/120
# 71/71 [==============================] - 5s 71ms/step - loss: 1.8657 - accuracy: 0.3456 - val_loss: 1.9146 - val_accuracy: 0.3151
# Epoch 23/120
# 71/71 [==============================] - 5s 70ms/step - loss: 1.8171 - accuracy: 0.3581 - val_loss: 1.9102 - val_accuracy: 0.3255
# Epoch 24/120
# 71/71 [==============================] - 5s 74ms/step - loss: 1.7643 - accuracy: 0.3839 - val_loss: 1.8881 - val_accuracy: 0.3520
# Epoch 25/120
# 71/71 [==============================] - 5s 72ms/step - loss: 1.7133 - accuracy: 0.3943 - val_loss: 1.8950 - val_accuracy: 0.3390
# Epoch 26/120
# 71/71 [==============================] - 5s 70ms/step - loss: 1.6742 - accuracy: 0.4016 - val_loss: 1.8992 - val_accuracy: 0.3581
# Epoch 27/120
# 71/71 [==============================] - 5s 71ms/step - loss: 1.6466 - accuracy: 0.4054 - val_loss: 1.9020 - val_accuracy: 0.3355
# Epoch 28/120
# 71/71 [==============================] - 5s 72ms/step - loss: 1.6158 - accuracy: 0.4303 - val_loss: 1.8953 - val_accuracy: 0.3416
# Epoch 29/120
# 71/71 [==============================] - 5s 70ms/step - loss: 1.5848 - accuracy: 0.4397 - val_loss: 1.8630 - val_accuracy: 0.3603
# Epoch 30/120
# 71/71 [==============================] - 5s 71ms/step - loss: 1.5448 - accuracy: 0.4583 - val_loss: 1.9038 - val_accuracy: 0.3485
# Epoch 31/120
# 71/71 [==============================] - 5s 78ms/step - loss: 1.5313 - accuracy: 0.4641 - val_loss: 1.8365 - val_accuracy: 0.3754
# Epoch 32/120
# 71/71 [==============================] - 6s 78ms/step - loss: 1.5208 - accuracy: 0.4697 - val_loss: 1.8773 - val_accuracy: 0.3574
# Epoch 33/120
# 71/71 [==============================] - 5s 75ms/step - loss: 1.4876 - accuracy: 0.4837 - val_loss: 1.8577 - val_accuracy: 0.3839
# Epoch 34/120
# 71/71 [==============================] - 5s 77ms/step - loss: 1.4599 - accuracy: 0.4968 - val_loss: 1.8681 - val_accuracy: 0.3763
# Epoch 35/120
# 71/71 [==============================] - 5s 74ms/step - loss: 1.4372 - accuracy: 0.5059 - val_loss: 1.8298 - val_accuracy: 0.3792
# Epoch 36/120
# 71/71 [==============================] - 6s 84ms/step - loss: 1.5244 - accuracy: 0.4792 - val_loss: 1.9384 - val_accuracy: 0.3437
# Epoch 37/120
# 71/71 [==============================] - 7s 102ms/step - loss: 1.5007 - accuracy: 0.4725 - val_loss: 1.8644 - val_accuracy: 0.3884
# Epoch 38/120
# 71/71 [==============================] - 6s 91ms/step - loss: 1.4332 - accuracy: 0.4966 - val_loss: 1.8983 - val_accuracy: 0.3770
# Epoch 39/120
# 71/71 [==============================] - 6s 90ms/step - loss: 1.4072 - accuracy: 0.5114 - val_loss: 1.8937 - val_accuracy: 0.3950
# Epoch 40/120
# 71/71 [==============================] - 6s 85ms/step - loss: 1.3848 - accuracy: 0.5217 - val_loss: 1.8748 - val_accuracy: 0.3851
# Epoch 41/120
# 71/71 [==============================] - 6s 86ms/step - loss: 1.3767 - accuracy: 0.5241 - val_loss: 1.8527 - val_accuracy: 0.3839
# Epoch 42/120
# 71/71 [==============================] - 6s 89ms/step - loss: 1.3452 - accuracy: 0.5397 - val_loss: 1.8947 - val_accuracy: 0.3737
# Epoch 43/120
# 71/71 [==============================] - 6s 86ms/step - loss: 1.3325 - accuracy: 0.5419 - val_loss: 1.8455 - val_accuracy: 0.4085
# Epoch 44/120
# 71/71 [==============================] - 6s 90ms/step - loss: 1.3303 - accuracy: 0.5459 - val_loss: 1.9214 - val_accuracy: 0.4021
# Epoch 45/120
# 71/71 [==============================] - 6s 91ms/step - loss: 1.2971 - accuracy: 0.5635 - val_loss: 1.8519 - val_accuracy: 0.4016
# Epoch 46/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.2805 - accuracy: 0.5608 - val_loss: 1.8180 - val_accuracy: 0.4217
# Epoch 47/120
# 71/71 [==============================] - 7s 93ms/step - loss: 1.2638 - accuracy: 0.5672 - val_loss: 1.8503 - val_accuracy: 0.4200
# Epoch 48/120
# 71/71 [==============================] - 6s 92ms/step - loss: 1.2489 - accuracy: 0.5690 - val_loss: 1.8984 - val_accuracy: 0.4075
# Epoch 49/120
# 71/71 [==============================] - 7s 95ms/step - loss: 1.2296 - accuracy: 0.5781 - val_loss: 1.8045 - val_accuracy: 0.4266
# Epoch 50/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.2185 - accuracy: 0.5784 - val_loss: 1.8852 - val_accuracy: 0.4210
# Epoch 51/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.1729 - accuracy: 0.6026 - val_loss: 1.8093 - val_accuracy: 0.4399
# Epoch 52/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.1461 - accuracy: 0.6126 - val_loss: 1.8350 - val_accuracy: 0.4363
# Epoch 53/120
# 71/71 [==============================] - 7s 95ms/step - loss: 1.1457 - accuracy: 0.6126 - val_loss: 1.8602 - val_accuracy: 0.4437
# Epoch 54/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.1149 - accuracy: 0.6148 - val_loss: 1.8409 - val_accuracy: 0.4429
# Epoch 55/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.1035 - accuracy: 0.6259 - val_loss: 1.9265 - val_accuracy: 0.4389
# Epoch 56/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.0842 - accuracy: 0.6295 - val_loss: 1.9460 - val_accuracy: 0.4309
# Epoch 57/120
# 71/71 [==============================] - 7s 95ms/step - loss: 1.1142 - accuracy: 0.6255 - val_loss: 1.8544 - val_accuracy: 0.4382
# Epoch 58/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.0650 - accuracy: 0.6413 - val_loss: 1.8807 - val_accuracy: 0.4236
# Epoch 59/120
# 71/71 [==============================] - 7s 95ms/step - loss: 1.0708 - accuracy: 0.6348 - val_loss: 1.9831 - val_accuracy: 0.4316
# Epoch 60/120
# 71/71 [==============================] - 7s 94ms/step - loss: 1.0332 - accuracy: 0.6577 - val_loss: 2.0022 - val_accuracy: 0.4297
# Epoch 61/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.0284 - accuracy: 0.6519 - val_loss: 1.9616 - val_accuracy: 0.4373
# Epoch 62/120
# 71/71 [==============================] - 7s 94ms/step - loss: 0.9990 - accuracy: 0.6637 - val_loss: 1.8707 - val_accuracy: 0.4536
# Epoch 63/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.0213 - accuracy: 0.6630 - val_loss: 2.0199 - val_accuracy: 0.4342
# Epoch 64/120
# 71/71 [==============================] - 7s 95ms/step - loss: 1.0044 - accuracy: 0.6606 - val_loss: 1.9453 - val_accuracy: 0.4526
# Epoch 65/120
# 71/71 [==============================] - 7s 98ms/step - loss: 1.0430 - accuracy: 0.6666 - val_loss: 2.1233 - val_accuracy: 0.3182
# Epoch 66/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.8008 - accuracy: 0.4114 - val_loss: 1.8645 - val_accuracy: 0.3451
# Epoch 67/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.4337 - accuracy: 0.4948 - val_loss: 1.7474 - val_accuracy: 0.4578
# Epoch 68/120
# 71/71 [==============================] - 7s 98ms/step - loss: 1.2569 - accuracy: 0.5628 - val_loss: 1.7640 - val_accuracy: 0.4448
# Epoch 69/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.1745 - accuracy: 0.5906 - val_loss: 1.7847 - val_accuracy: 0.4444
# Epoch 70/120
# 71/71 [==============================] - 7s 98ms/step - loss: 1.1348 - accuracy: 0.6079 - val_loss: 1.7808 - val_accuracy: 0.4567
# Epoch 71/120
# 71/71 [==============================] - 7s 95ms/step - loss: 1.0846 - accuracy: 0.6264 - val_loss: 1.7994 - val_accuracy: 0.4467
# Epoch 72/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.0630 - accuracy: 0.6359 - val_loss: 1.8050 - val_accuracy: 0.4427
# Epoch 73/120
# 71/71 [==============================] - 7s 97ms/step - loss: 1.0294 - accuracy: 0.6419 - val_loss: 1.8824 - val_accuracy: 0.4382
# Epoch 74/120
# 71/71 [==============================] - 7s 95ms/step - loss: 1.0085 - accuracy: 0.6568 - val_loss: 1.9602 - val_accuracy: 0.4252
# Epoch 75/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.9906 - accuracy: 0.6650 - val_loss: 1.9103 - val_accuracy: 0.4385
# Epoch 76/120
# 71/71 [==============================] - 7s 94ms/step - loss: 0.9774 - accuracy: 0.6666 - val_loss: 1.9725 - val_accuracy: 0.4444
# Epoch 77/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.9436 - accuracy: 0.6824 - val_loss: 1.9739 - val_accuracy: 0.4167
# Epoch 78/120
# 71/71 [==============================] - 7s 94ms/step - loss: 0.9305 - accuracy: 0.6833 - val_loss: 1.9629 - val_accuracy: 0.4363
# Epoch 79/120
# 71/71 [==============================] - 7s 96ms/step - loss: 1.0798 - accuracy: 0.6390 - val_loss: 1.8540 - val_accuracy: 0.4344
# Epoch 80/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.9670 - accuracy: 0.6748 - val_loss: 1.9008 - val_accuracy: 0.4297
# Epoch 81/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.9213 - accuracy: 0.6915 - val_loss: 1.9726 - val_accuracy: 0.4174
# Epoch 82/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.9092 - accuracy: 0.6973 - val_loss: 1.9296 - val_accuracy: 0.4292
# Epoch 83/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.9136 - accuracy: 0.6946 - val_loss: 1.9756 - val_accuracy: 0.4347
# Epoch 84/120
# 71/71 [==============================] - 7s 100ms/step - loss: 0.8661 - accuracy: 0.7150 - val_loss: 2.0114 - val_accuracy: 0.4255
# Epoch 85/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.8755 - accuracy: 0.7055 - val_loss: 2.0838 - val_accuracy: 0.4437
# Epoch 86/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.8697 - accuracy: 0.7095 - val_loss: 2.1363 - val_accuracy: 0.4222
# Epoch 87/120
# 71/71 [==============================] - 7s 103ms/step - loss: 0.8521 - accuracy: 0.7146 - val_loss: 2.1011 - val_accuracy: 0.4292
# Epoch 88/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.8413 - accuracy: 0.7204 - val_loss: 2.1857 - val_accuracy: 0.4451
# Epoch 89/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.8361 - accuracy: 0.7168 - val_loss: 2.1394 - val_accuracy: 0.4344
# Epoch 90/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.8275 - accuracy: 0.7264 - val_loss: 2.2278 - val_accuracy: 0.4394
# Epoch 91/120
# 71/71 [==============================] - 7s 99ms/step - loss: 0.8257 - accuracy: 0.7262 - val_loss: 2.0442 - val_accuracy: 0.4373
# Epoch 92/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.8049 - accuracy: 0.7364 - val_loss: 2.1790 - val_accuracy: 0.4283
# Epoch 93/120
# 71/71 [==============================] - 7s 100ms/step - loss: 0.7916 - accuracy: 0.7395 - val_loss: 2.0183 - val_accuracy: 0.4479
# Epoch 94/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.7660 - accuracy: 0.7453 - val_loss: 2.1269 - val_accuracy: 0.4295
# Epoch 95/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.7659 - accuracy: 0.7495 - val_loss: 2.1772 - val_accuracy: 0.4434
# Epoch 96/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.7665 - accuracy: 0.7499 - val_loss: 2.1952 - val_accuracy: 0.4429
# Epoch 97/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.7550 - accuracy: 0.7448 - val_loss: 2.4253 - val_accuracy: 0.4311
# Epoch 98/120
# 71/71 [==============================] - 7s 97ms/step - loss: 0.7693 - accuracy: 0.7457 - val_loss: 2.1832 - val_accuracy: 0.4295
# Epoch 99/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.7466 - accuracy: 0.7537 - val_loss: 2.1771 - val_accuracy: 0.4262
# Epoch 100/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.7281 - accuracy: 0.7584 - val_loss: 2.0979 - val_accuracy: 0.4354
# Epoch 101/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.7621 - accuracy: 0.7475 - val_loss: 2.1770 - val_accuracy: 0.4441
# Epoch 102/120
# 71/71 [==============================] - 7s 97ms/step - loss: 0.7699 - accuracy: 0.7453 - val_loss: 2.0752 - val_accuracy: 0.4465
# Epoch 103/120
# 71/71 [==============================] - 7s 101ms/step - loss: 0.7065 - accuracy: 0.7664 - val_loss: 2.2004 - val_accuracy: 0.4389
# Epoch 104/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.7405 - accuracy: 0.7577 - val_loss: 2.2341 - val_accuracy: 0.4406
# Epoch 105/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.7322 - accuracy: 0.7586 - val_loss: 2.2401 - val_accuracy: 0.4472
# Epoch 106/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6963 - accuracy: 0.7642 - val_loss: 2.2686 - val_accuracy: 0.4536
# Epoch 107/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.6914 - accuracy: 0.7653 - val_loss: 2.2248 - val_accuracy: 0.4370
# Epoch 108/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.7013 - accuracy: 0.7628 - val_loss: 2.1253 - val_accuracy: 0.4668
# Epoch 109/120
# 71/71 [==============================] - 7s 94ms/step - loss: 0.6766 - accuracy: 0.7764 - val_loss: 2.4086 - val_accuracy: 0.4555
# Epoch 110/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.6629 - accuracy: 0.7753 - val_loss: 2.2987 - val_accuracy: 0.4455
# Epoch 111/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6567 - accuracy: 0.7782 - val_loss: 2.2402 - val_accuracy: 0.4590
# Epoch 112/120
# 71/71 [==============================] - 7s 96ms/step - loss: 0.6513 - accuracy: 0.7824 - val_loss: 2.2627 - val_accuracy: 0.4375
# Epoch 113/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6307 - accuracy: 0.7864 - val_loss: 2.3454 - val_accuracy: 0.4460
# Epoch 114/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6414 - accuracy: 0.7828 - val_loss: 2.5981 - val_accuracy: 0.4292
# Epoch 115/120
# 71/71 [==============================] - 7s 98ms/step - loss: 0.6218 - accuracy: 0.7875 - val_loss: 2.4953 - val_accuracy: 0.4439
# Epoch 116/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6243 - accuracy: 0.7904 - val_loss: 2.3778 - val_accuracy: 0.4425
# Epoch 117/120
# 71/71 [==============================] - 7s 97ms/step - loss: 0.6223 - accuracy: 0.7920 - val_loss: 2.2934 - val_accuracy: 0.4359
# Epoch 118/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6152 - accuracy: 0.7911 - val_loss: 2.5329 - val_accuracy: 0.4401
# Epoch 119/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6044 - accuracy: 0.7946 - val_loss: 2.5919 - val_accuracy: 0.4401
# Epoch 120/120
# 71/71 [==============================] - 7s 95ms/step - loss: 0.6192 - accuracy: 0.7895 - val_loss: 2.4990 - val_accuracy: 0.4394

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(X_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 40, 128)           66560
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 118,378
# Trainable params: 118,378
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 40, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 40, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 42, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 40, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 40, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 42, 1).
# 133/133 [==============================] - 3s 17ms/step - loss: 2.4990 - accuracy: 0.4394
# Pre-training accuracy: 43.9405%

# %%
score = model.evaluate(X_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(X_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.7972882986068726
# Testing Accuracy:  0.4394046664237976

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.4394046664237976

# %%
#model.predict_classes(X_test)
predict_x=model.predict(X_test) 
classes_x=np.argmax(predict_x,axis=1)
print(classes_x)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 40, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 40, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 42, 1).
# [8 8 8 ... 9 9 9]

# %%
# summarize history for accuracy
plt.plot(model_all.history['accuracy'])
plt.plot(model_all.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model_all.history['loss'])
plt.plot(model_all.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
train_hist = pd.DataFrame(model_all.history)
train_hist
# Out:
#          loss  accuracy  val_loss  val_accuracy
# 0    2.241795  0.168037  2.263523      0.162060
# 1    2.145198  0.207157  2.139548      0.210489
# 2    2.051667  0.242276  2.131414      0.180959
# 3    1.998243  0.254723  2.035370      0.273329
# 4    1.926193  0.280507  2.022197      0.275691
# ..        ...       ...       ...           ...
# 115  0.624253  0.790398  2.377766      0.442476
# 116  0.622347  0.791954  2.293450      0.435861
# 117  0.615156  0.791065  2.532905      0.440113
# 118  0.604353  0.794621  2.591931      0.440113
# 119  0.619227  0.789509  2.499022      0.439405
#
# [120 rows x 4 columns]

# %%
plt.figure(figsize=(20,8))
plt.plot(train_hist[['loss','val_loss']])
plt.legend(['Loss','Test Loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

plt.figure(figsize=(20,8))
plt.plot(train_hist[['accuracy','val_accuracy']])
plt.legend(['Train Accuracy','Test Accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
ytrue = np.argmax(y_test,axis=1)
ypred = np.argmax(model.predict(X_test),axis=1)
print('\nConfusion Matrix :\n\n')
print(confusion_matrix(ytrue,ypred))
print('\n\nClassification Report : \n\n',classification_report(ytrue,ypred))
# Out:
# Confusion Matrix :
#
#
# [[117   5  65  12  16  46   9  99  83  48]
#  [  9 130   5   3   4   3   0  12  22  33]
#  [ 24   1 289  32  13  23   3   3  82  30]
#  [ 16   1  76 225  33  15  12   7  89  26]
#  [ 39   1  18  71 202   5  10  97  27  30]
#  [107   2   7  75  17 189   4  36  42   4]
#  [  8   0   6  10  16   6 125   4   8   1]
#  [ 39  31   0  24 148   6   1 146  45  12]
#  [ 11  28  47  39   8   5   6   1 237  11]
#  [ 38  11  75  41  17   9   4   9  96 200]]
#
#
# Classification Report :
#
#                precision    recall  f1-score   support
#
#            0       0.29      0.23      0.26       500
#            1       0.62      0.59      0.60       221
#            2       0.49      0.58      0.53       500
#            3       0.42      0.45      0.44       500
#            4       0.43      0.40      0.41       500
#            5       0.62      0.39      0.48       483
#            6       0.72      0.68      0.70       184
#            7       0.35      0.32      0.34       452
#            8       0.32      0.60      0.42       393
#            9       0.51      0.40      0.45       500
#
#     accuracy                           0.44      4233
#    macro avg       0.48      0.47      0.46      4233
# weighted avg       0.45      0.44      0.44      4233
